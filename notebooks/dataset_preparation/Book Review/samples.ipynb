# %% [markdown]
# # Display Sample Records

# %%
import gzip
import json
import re
import os
import sys
import numpy as np
import pandas as pd

# %% [markdown]
# **Specify your directory here:**

# %%
DIR = '/Users/spartan/Projects/Deep-Learning-Based-Group-Recommender-System/data/raw'

# %% [markdown]
# **This function shows how to load datasets**

# %%
def load_data(file_name, head = 500):
    count = 0
    data = []
    with gzip.open(file_name) as fin:
        for l in fin:
            d = json.loads(l)
            count += 1
            data.append(d)
            
            # break if reaches the 100th line
            if (head is not None) and (count > head):
                break
    return data

# %% [markdown]
# **Load and display sample records of books**

# %%
full_poetry_books = load_data(os.path.join(DIR, 'goodreads_books_poetry.json.gz'))

# %%
print(' == sample record (books) ==')
display(np.random.choice(poetry_books))
# Out:
#  == sample record (books) ==
# {'isbn': '0393065243',
#  'text_reviews_count': '3',
#  'series': [],
#  'country_code': 'US',
#  'language_code': '',
#  'popular_shelves': [{'count': '21', 'name': 'to-read'},
#   {'count': '9', 'name': 'poetry'},
#   {'count': '2', 'name': 'currently-reading'},
#   {'count': '2', 'name': 'jewish'},
#   {'count': '2', 'name': 'israel'},
#   {'count': '1', 'name': 'read-2017'},
#   {'count': '1', 'name': 'to-read-2'},
#   {'count': '1', 'name': 'favorites'},
#   {'count': '1', 'name': 'books-you-should-read'},
#   {'count': '1', 'name': 'foreign-literature-in-translation'},
#   {'count': '1', 'name': 'translations'},
#   {'count': '1', 'name': 'unsorted'},
#   {'count': '1', 'name': 'to-be-purchased'},
#   {'count': '1', 'name': 'to-buy'}],
#  'asin': '',
#  'is_ebook': 'false',
#  'average_rating': '3.93',
#  'kindle_asin': '',
#  'similar_books': [],
#  'description': 'In poems about fathers and daughters, men and women, kings and their subjects, the precarious position of women and the plight of Palestinians under the Occupation, Dahlia Ravikovitch articulates the painful asymmetries of power. The extraordinary stylistic range of her poetry reveals her mastery of the verbal art.\nfrom "Clockwork Doll"\nI was a clockwork doll, but then\nThat night I turned round and around\nAnd fell on my face, cracked on the ground,\nAnd they tried to piece me together again.\nThen once more I was a proper doll\nAnd all my manner was nice and polite.\nBut I became damaged goods that night,\nA fractured twig poised for a fall.',
#  'format': 'Hardcover',
#  'link': 'https://www.goodreads.com/book/show/6383302-hovering-at-a-low-altitude',
#  'authors': [{'author_id': '229216', 'role': ''},
#   {'author_id': '93443', 'role': 'Translator'},
#   {'author_id': '737734', 'role': 'Translator'}],
#  'publisher': 'W. W. Norton & Company',
#  'num_pages': '272',
#  'publication_day': '27',
#  'isbn13': '9780393065244',
#  'publication_month': '4',
#  'edition_information': '',
#  'publication_year': '2009',
#  'url': 'https://www.goodreads.com/book/show/6383302-hovering-at-a-low-altitude',
#  'image_url': 'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png',
#  'book_id': '6383302',
#  'ratings_count': '13',
#  'work_id': '6571337',
#  'title': 'Hovering at a Low Altitude: The Collected Poetry of Dahlia Ravikovitch',
#  'title_without_series': 'Hovering at a Low Altitude: The Collected Poetry of Dahlia Ravikovitch'}

# %% [markdown]
# **Load and display sample records of user-book interactions (shelves)**

# %%
interactions = load_data(os.path.join(DIR, 'goodreads_interactions_poetry.json.gz'))

# %%
print(' == sample record (interaction) ==')
display(np.random.choice(interactions))
# Out:
#  == sample record (interaction) ==
# {'user_id': '90181ceb30afe97805078c900f5ec53b',
#  'book_id': '6585485',
#  'review_id': '51dffcb515eb0d52781654d248140f61',
#  'is_read': True,
#  'rating': 5,
#  'review_text_incomplete': '',
#  'date_added': 'Sat Jul 14 02:30:51 -0700 2012',
#  'date_updated': 'Sat Jul 14 02:31:12 -0700 2012',
#  'read_at': 'Sat Jul 14 02:31:12 -0700 2012',
#  'started_at': ''}

# %% [markdown]
# ## Data Sampling

# %% [markdown]
# #### Since dataset is too large to handle in limited resource, we will sample 200k samples.

# %%
# Load Book
full_book_df = pd.read_json(os.path.join(DIR, 'goodreads_books_poetry.json.gz'), lines=True,)

# load Interactions
full_interactions_df = pd.read_json(os.path.join(DIR, 'goodreads_interactions_poetry.json.gz'), lines=True)

# Load Reviews
full_reviews_df = pd.read_json(os.path.join(DIR, 'goodreads_reviews_poetry.json.gz'), lines=True)

# %%
SAMPLE_SIZE = 200000

# %%
book_genere_info = pd.read_json('/Users/spartan/Downloads/goodreads_book_genres_initial.json', lines=True)

# %%
total_genres = set()

def get_total_genres(genres):
    for genre in genres:
        total_genres.add(genre)
book_genere_info['genres'].apply(lambda x: get_total_genres(x.keys()))

# user_interest = np.random.choice(list(total_genres), SAMPLE_SIZE)
# Out:
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None
#            ...
# 2360650    None
# 2360651    None
# 2360652    None
# 2360653    None
# 2360654    None
# Name: genres, Length: 2360655, dtype: object

# %%
interactions_df_subset = interactions_df[:SAMPLE_SIZE]
interactions_df_subset.drop(['date_updated','read_at','started_at'], axis=1, inplace=True)
# Out:
# /var/folders/dh/ln04g3510214yht30l2_xsw00000gr/T/ipykernel_17700/687804278.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   interactions_df_subset.drop(['date_updated','read_at','started_at'], axis=1, inplace=True)

# %%
t = interactions_df_subset.user_id.value_counts()
# Generate features for each user
user_interest = np.random.choice(list(total_genres), len(t))
user_age = np.random.randint(18, 100, len(t))

# %%
user_df = pd.DataFrame(data = {"general_interest": user_interest, "Age" : user_age}, index = t.index)

# %%
user_df.reset_index(inplace=True)

# %%
user_df.rename(columns={'index':'user_id'}, inplace=True)

# %%
user_df.head()
# Out:
#                             user_id                        general_interest  \
# 0  55bea8421fbd1f96790bcaa6302b5aab                mystery, thriller, crime
# 1  3f0d11375b87707eac2137d68564a0b7  history, historical fiction, biography
# 2  fba91ff84f33aab3a03852afca1f9942                         comics, graphic
# 3  2a51426b2df337ff8eae7846217ad083                                children
# 4  cbcbba3acce70042b61df6fcb2dd3781                mystery, thriller, crime
#
#    Age
# 0   40
# 1   72
# 2   92
# 3   98
# 4   96

# %%
user_df.to_csv('/Users/spartan/Projects/Deep-Learning-Based-Group-Recommender-System/data/interim/users_data.csv', index=False)

# %%
full_book_df = full_book_df[['book_id','title','ratings_count','country_code','is_ebook','average_rating']]

# %%
full_reviews_df
# Out:
#                                  user_id  book_id  \
# 0       3ca7375dba942a760e53b726c472a7dd   402128
# 1       0ef32090550901ead25cb0ea21c4d36b    92270
# 2       0ef32090550901ead25cb0ea21c4d36b   908708
# 3       d37b46b2190ed7c518259f29b47a9b36   253264
# 154553  Fri Sep 21 10:09:53 -0700 2012  Tue Sep 04 14:58:29 -0700 2012
# 154554  Mon Sep 03 00:00:00 -0700 2012
#
#         n_votes  n_comments
# 0             0           0
# 1             0           0
# 2             0           0
# 3             1           0
# 4             0           0
# ...         ...         ...
# 154550        0           0
# 154551        1           0
# 154552        4           0
# 154553        4           1
# 154554        1           0
#
# [154555 rows x 11 columns]

# %%
df1 = full_book_df[full_book_df['book_id'].isin(interactions_df_subset.book_id)]

# %%
df1.to_csv('/Users/spartan/Projects/Deep-Learning-Based-Group-Recommender-System/data/interim/books_data.csv', index=False)

# %%
interactions_df_subset['date_added'] = pd.to_datetime(interactions_df_subset['date_added'])
# Out:
# /var/folders/dh/ln04g3510214yht30l2_xsw00000gr/T/ipykernel_17700/1463593431.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   interactions_df_subset['date_added'] = pd.to_datetime(interactions_df_subset['date_added'])

# %%
interactions_df_subset.to_csv('/Users/spartan/Projects/Deep-Learning-Based-Group-Recommender-System/data/interim/interactions_data.csv', index=False)

# %% [markdown]
# ## convert user_id and book book_id to integer

# %%
interactions_df = pd.read_csv('/Users/spartan/Projects/Deep-Learning-Based-Group-Recommender-System/data/interim/interactions_data.csv')

# %%
u_ids = interactions_df.user_id

# %%
i_ids = interactions_df.book_id

# %%
user_dict={}
for index, value in np.ndenumerate(u_ids.unique()):
    user_dict[value] = index[0]+1

# %%
len(user_dict)
# Out:
# 20627

# %%
item_dict={}
for index, value in np.ndenumerate(i_ids.unique()):
    item_dict[value] = index[0]+1

# %%
item_dict
# Out:
# {1384: 1,
#  1376: 2,
#  30119: 3,
#  24769928: 4,
#  240007: 5,
#  23513349: 6,
#  17805212: 7,
#  10843755: 8,
#  2696: 9,
#  30118: 10,
#  23919: 11,
#  1420: 12,
#  6295: 13,
#  17707772: 14,
#  20821284: 15,
#  2547: 16,
#  18743: 17,
#  52820: 18,
#  543235: 19,
#  1381: 20,
#  15997: 21,
#  28188156: 22,
#  22324396: 23,
#  20177773: 24,
#  21852315: 25,
#  16180680: 26,
#  1724365: 27,
#  1371: 28,
#  131885: 29,
#  35606560: 30,
#  129636: 31,
#  22151696: 32,
#  11904233: 33,
#  262304: 34,
#  15812153: 35,
#  95819: 36,
#  53022: 37,
#  42038: 38,
#  27494: 39,
#  402128: 40,
#  26114416: 41,
#  25115796: 42,
#  3611540: 43,
#  23534: 44,
#  20613761: 45,
#  92270: 46,
#  12907847: 47,
#  9583799: 48,
#  908708: 49,
#  19351: 50,
#  12914: 51,
#  253264: 52,
#  28212625: 53,
#  845331: 54,
#  70885: 55,
#  15829076: 56,
#  676: 57,
#  1432: 58,
#  6798263: 59,
#  29875917: 60,
#  25937948: 61,
#  28116744: 62,
#  24611931: 63,
#  61049: 64,
#  46231: 65,
#  7428663: 66,
#  1715: 67,
#  1519: 68,
#  32552: 69,
#  1503869: 70,
#  195769: 71,
#  2325390: 72,
#  732562: 73,
#  765172: 74,
#  16075147: 75,
#  13588404: 76,
#  78249: 77,
#  44178: 78,
#  119841: 79,
#  12955405: 80,
#  17157815: 81,
#  14706: 82,
#  13425881: 83,
#  12955393: 84,
#  66414: 85,
#  12375480: 86,
#  13105527: 87,
#  17279013: 88,
#  5289: 89,
#  764332: 90,
#  18144035: 91,
#  9444: 92,
#  18369456: 93,
#  1587998: 904,
#  12225739: 905,
#  709960: 906,
#  14820809: 907,
#  15798665: 908,
#  341717: 909,
#  13143235: 910,
#  17384233: 911,
#  15834621: 912,
#  620722: 913,
#  12906786: 914,
#  14863762: 915,
#  13159178: 916,
#  6515163: 917,
#  7493149: 918,
#  13722316: 919,
#  13642602: 920,
#  11089150: 921,
#  10182327: 922,
#  18486: 923,
#  2116092: 924,
#  725805: 925,
#  7680325: 926,
#  11085473: 927,
#  2318001: 928,
#  368564: 929,
#  8008082: 930,
#  8822290: 931,
#  12908947: 932,
#  12909209: 933,
#  9371035: 934,
#  138643: 935,
#  13202105: 936,
#  29476678: 937,
#  72588: 938,
#  7044534: 939,
#  47721: 940,
#  30123: 941,
#  36310: 942,
#  376329: 943,
#  65349: 944,
#  223394: 945,
#  12825846: 946,
#  296866: 947,
#  916114: 948,
#  2455: 949,
#  24575346: 950,
#  2713: 951,
#  151809: 952,
#  953814: 953,
#  11251972: 954,
#  231558: 955,
#  96259: 956,
#  256034: 957,
#  130403: 958,
#  97684: 959,
#  6759594: 960,
#  752868: 961,
#  27418: 962,
#  695009: 963,
#  77903: 964,
#  50464: 965,
#  1948294: 966,
#  23015468: 967,
#  23635465: 968,
#  25325367: 969,
#  28118947: 970,
#  30759223: 971,
#  37804: 972,
#  694475: 973,
#  3210714: 974,
#  1110268: 975,
#  28939029: 976,
#  6990156: 977,
#  13577823: 978,
#  381112: 979,
#  18394093: 980,
#  9269669: 981,
#  1606846: 982,
#  271073: 983,
#  13514106: 984,
#  17448181: 985,
#  7057210: 986,
#  9269144: 987,
#  7348445: 988,
#  24874364: 989,
#  13330670: 990,
#  18869234: 991,
#  19134941: 992,
#  25332008: 993,
#  11715980: 994,
#  67377: 995,
#  67376: 996,
#  7261774: 997,
#  17934511: 998,
#  20175409: 999,
#  458787: 1000,
#  ...}

# %%
interactions_df['user_id'] = interactions_df['user_id'].map(user_dict)

# %%
interactions_df['book_id'] = interactions_df['book_id'].map(item_dict)

# %%
interactions_df.to_csv('/Users/spartan/Projects/Deep-Learning-Based-Group-Recommender-System/data/interim/interactions_data.csv', index=False)

# %%
books_df = pd.read_csv('/Users/spartan/Projects/Deep-Learning-Based-Group-Recommender-System/data/interim/books_data.csv')
user_df = pd.read_csv('/Users/spartan/Projects/Deep-Learning-Based-Group-Recommender-System/data/interim/users_data.csv')

# %%
books_df['book_id'] = books_df['book_id'].map(item_dict)
user_df['user_id'] = user_df['user_id'].map(user_dict)

# %%
user_df.to_csv('/Users/spartan/Projects/Deep-Learning-Based-Group-Recommender-System/data/interim/users_data.csv', index=False)
books_df.to_csv('/Users/spartan/Projects/Deep-Learning-Based-Group-Recommender-System/data/interim/books_data.csv', index=False)

# %% [markdown]
# #### process time attribute

# %%
interactionms = pd.read_csv('/Users/spartan/Projects/Deep-Learning-Based-Group-Recommender-System/data/interim/interactions_data.csv')

# %%
interactionms['timestamp'] = interactionms['date_added'].apply(lambda x: int(pd.Timestamp(x).timestamp()))

# %%
interactionms.reset_index(inplace=True)

# %%
interactionms.rename(columns={'index':'review_id'}, inplace=True)

# %%
interactionms.drop(['review_id'], axis=1, inplace=True)

# %%
interactionms.to_csv('/Users/spartan/Projects/Deep-Learning-Based-Group-Recommender-System/data/interim/interactions_data.csv', index=False)

# %%
ratings = np.random.randint(1, 6, len(interactionms))

# %%
interactionms['ratings'] = ratings

# %%
interactionms.drop(['rating'], axis=1, inplace=True)
